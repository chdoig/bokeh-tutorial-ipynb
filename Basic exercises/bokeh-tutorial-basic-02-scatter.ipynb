# %% [markdown]
# ## <div style="float:left">
#     <a href="http://bokeh.pydata.org/">
#     <img src="http://bokeh.pydata.org/_static/bokeh-transparent.png" style="display:inline-block; width:90px"></a>
#     <h1  style="display:inline-block">Bokeh tutorial - Basic Exercises</h1>
# </div>

# %% [markdown]
# This is the IPython Notebook version of the Bokeh Tutorial available at http://bokeh.pydata.org/tutorial/basic.html

# %%
import bokeh.bokeh_magic
# %bokeh --notebook
# Out:
# Bokeh magic loaded.
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#         <style>
#             /* BEGIN /Users/Christine/anaconda/lib/python2.7/site-packages/bokeh/server/static/css/bokeh.min.css */
#             /*!
#              * Bootstrap v2.0.4
#              *
#              * Copyright 2012 Twitter, Inc
#              * Licensed under the Apache License v2.0
#              * http://www.apache.org/licenses/LICENSE-2.0
#              *
#              * Designed and built with all the love in the world @twitter by @mdo and @fat.
#              */.bokeh article,.bokeh aside,.bokeh details,.bokeh figcaption,.bokeh figure,.bokeh footer,.bokeh header,.bokeh hgroup,.bokeh nav,.bokeh section{display:block}.bokeh audio,.bokeh canvas,.bokeh video{display:inline-block}.bokeh audio:not([controls]){display:none}.bokeh html{font-size:100%;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}.bokeh a:focus{outline:thin dotted #333;outline:5px auto -webkit-focus-ring-color;outline-offset:-2px}.bokeh a:hover,.bokeh a:active{outline:0}.bokeh sub,.bokeh sup{position:relative;font-size:75%;line-height:0;vertical-align:baseline}.bokeh sup{top:-.5em}.bokeh sub{bottom:-.25em}.bokeh img{max-width:100%;vertical-align:middle;border:0;-ms-interpolation-mode:bicubic}.bokeh #map_canvas img{max-width:none}.bokeh button,.bokeh input,.bokeh select,.bokeh textarea{margin:0;font-size:100%;vertical-align:middle}.bokeh button,.bokeh input{line-height:normal}.bokeh button::-moz-focus-inner,.bokeh input::-moz-focus-inner{padding:0;border:0}.bokeh button,.bokeh input[type=button],.bokeh input[type=reset],.bokeh input[type=submit]{cursor:pointer;-webkit-appearance:button}.bokeh input[type=search]{-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box;-webkit-appearance:textfield}.bokeh input[type=search]::-webkit-search-decoration,.bokeh input[type=search]::-webkit-search-cancel-button{-webkit-appearance:none}.bokeh textarea{overflow:auto;vertical-align:top}.bokeh .clearfix{}.bokeh .clearfix:before,.bokeh .clearfix:after{display:table;content:""}.bokeh .clearfix:after{clear:both}.bokeh .hide-text{font:0/0 a;color:transparent;text-shadow:none;background-color:transparent;border:0}.bokeh .input-block-level{display:block;width:100%;min-height:28px;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;-ms-box-sizing:border-box;box-sizing:border-box}.bokeh body{margin:0;font-family:"Helvetica Neue",Helvetica,Arial,sans-serif;font-size:13px;line-height:18px;color:#333;background-color:#fff}.bokeh a{color:#08c;text-decoration:none}.bokeh a:hover{color:#005580;text-decoration:underline}.bokeh .row{margin-left:-20px}.bokeh .row:before,.bokeh .row:after{display:table;content:""}.bokeh .row:after{clear:both}.bokeh [class*=span]{float:left;margin-left:20px}.bokeh .container,.bokeh .navbar-fixed-top .container,.bokeh .navbar-fixed-bottom .container{width:940px}.bokeh .span12{width:940px}.bokeh .span11{width:860px}.bokeh .span10{width:780px}.bokeh .span9{width:700px}.bokeh .span8{width:620px}.bokeh .span7{width:540px}.bokeh .span6{width:460px}.bokeh .span5{width:380px}.bokeh .span4{width:300px}.bokeh .span3{width:220px}.bokeh .span2{width:140px}.bokeh .span1{width:60px}.bokeh .offset12{margin-left:980px}.bokeh .offset11{margin-left:900px}.bokeh .offset10{margin-left:820px}.bokeh .offset9{margin-left:740px}.bokeh .offset8{margin-left:660px}.bokeh .offset7{margin-left:580px}.bokeh .offset6{margin-left:500px}.bokeh .offset5{margin-left:420px}.bokeh .offset4{margin-left:340px}.bokeh .offset3{margin-left:260px}.bokeh .offset2{margin-left:180px}.bokeh .offset1{margin-left:100px}.bokeh .row-fluid{width:100%}.bokeh .row-fluid:before,.bokeh .row-fluid:after{display:table;content:""}.bokeh .row-fluid:after{clear:both}.bokeh .row-fluid [class*=span]{display:block;float:left;width:100%;min-height:28px;margin-left:2.127659574%;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;-ms-box-sizing:border-box;box-sizing:border-box}.bokeh .row-fluid [class*=span]:first-child{margin-left:0}.bokeh .row-fluid .span12{width:99.99999998999999%}.bokeh .row-fluid .span11{width:91.489361693%}.bokeh .row-fluid .span10{width:82.97872339599999%}.bokeh .row-fluid .span9{width:74.468085099%}.bokeh .row-fluid .span8{width:65.95744680199999%}.bokeh .row-fluid .span7{width:57.446808505%}.bokeh .row-fluid .span6{width:48.93617020799999%}.bokeh .row-fluid .span5{width:40.425531911%}.bokeh .row-fluid .span4{width:31.914893614%}.bokeh .row-fluid .span3{width:23.404255317%}.bokeh .row-fluid .span2{width:14. ...

# %% [markdown]
# ## 2. Scattering Points

# %%
from __future__ import division

import numpy as np
from six.moves import zip
from bokeh.plotting import *
from bokeh.objects import Range1d

# %%
# Recreate the Fermat spiral from the last exercise, with some different scalings
# and number of turnings
theta1 = np.linspace(0, 256*np.pi, 500)[1:]
f1 = theta1**(1/2)
x1 = 0.5*f1*np.cos(theta1)
y1 = 0.5*f1*np.sin(theta1)

theta2 = np.linspace(0, 96*np.pi, 500)[1:]
f2 = theta2**(1/2)
x2 = f2*f2*np.cos(theta2)
y2 = f2*f2*np.sin(theta2)

theta3 = np.linspace(0, 32*np.pi, 500)[1:]
f3 = 2*theta3**(1/2)
x3 = 2*f3*np.cos(theta3)
y3 = 2*f3*np.sin(theta3)

# %%
# Create a set of tools to use
TOOLS="pan,wheel_zoom,box_zoom,reset,previewsave"

# %%
# EXERCISE: create two Range1d objects to reuse in the plots. Use the [-20, 20]
# for the bounds.
xr = Range1d(start=-20, end=20)
yr = Range1d(start=-20, end=20)

# %%
# EXERCISE: Plot all the sets of points on different plots. Use the ranges above
# for x_range and y_range. Set different colors as well. Try setting line_color
# and fill_color instead of just color. You can also set alpha, line_alpha, and
# fill_alpha if you like. Set tools to TOOLS on the first renderer. Change
# the value of the 'marker' parameter, "circle", "square", "triangle", etc. One
# example is given

# %%
scatter(x1, y1, size=12, color="red", alpha=0.5,
        x_range=xr, y_range=yr, tools=TOOLS)
# %bokeh --show
# Out:
# Automatic show() is enabled.
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#         <script type="text/javascript">
#             var all_models = [{"attributes": {"column_names": ["x", "y"], "doc": null, "selected": [], "discrete_ranges": {}, "cont_ranges": {}, "data": {"y": [0.634236018676442, -0.07339007932661745, -1.0911744864689834, 0.206883634323373, 1.3897744763609043, -0.37794764711672, -1.611001026874622, 0.577333305825324, 1.7765992395462376, -0.7987068025104332, -1.8955626110323507, 1.0369353085735085, 1.972384975755608, -1.2874952628218377, -2.009638097421562, 1.5462161335248925, 2.0090145596627385, -1.8091576618082326, -1.9718209324049314, 2.072549776256705, 1.8992363470140068, -2.3327653151753656, -1.7924577387971148, 2.5863112487815965, 1.6527848377452106, -2.8298308543037294, -1.481670497238125, 3.060112542350688, 1.2807496701823042, -3.274102716219586, -1.0518544012990874, 3.4689209756071984, 0.7970191412532495, -3.6418765179162977, -0.5184790250638179, 3.7904849212566343, 0.21866281489361447, -3.9124847044693256, 0.09981834555383237, 4.005853200260817, -0.43418555154857513, -4.068821375508082, 0.7815095254599608, 4.099887304131736, -1.1387302949410312, -4.097828052324726, 1.5026787664880517, 4.061709779343205, -1.8700998532866944, -3.990895893269013, 2.237676851354443, 3.8850531325372057, -2.6020567813451025, -3.744155472136654, 2.959876429335713, 3.5684857792363625, -3.3077888312937698, -3.3586351672112165, 3.6424899546137297, 3.115500020047846, -3.9607453373796577, -2.8402766811475177, 4.259416452727287, 2.5344538217516805, -4.535486572430721, -2.1998025246542605, 4.786085911031702, 1.8383641385495721, -5.008515839739242, -1.4524359772632904, 5.200271968127295, 1.0445549561810188, -5.359065901461125, -0.6174792753596878, 5.48284549234217, 0.1741682749988343, -5.569813417296379, 0.2822393959105112, 5.618443921924654, -0.7484491429431175, -5.627497592247689, 1.2210351540021789, 5.59603402485138, -1.696466312406872, -5.523422284295386, 2.171133106106011, 5.409349052896602, -2.641375335144226, -5.253824395339564, 3.1035104123212873, 5.057185078483703, -3.5538620463448765, -4.820095405119138, 3.988789092719112, 4.5435455391355655, -4.404714355164193, -4.228847318490677, 4.798153119550055, 3.877627571357431, -5.165741203144841, -3.49181896976028, 5.504262304440843, 3.0736484737441434, -5.81067444289343, -2.6256234375156606, 6.08213528357743, 2.15051546693253, -6.316026148987256, -1.6513421350435695, 6.509974528933155, 1.1313466789901285, -6.6618749096581595, -0.5939758173333501, 6.769907754842746, 0.042855841658918, -6.832556484003839, 0.5182328499791816, 6.848622307833355, -1.0853825976922238, -6.817236795165087, 1.6545865111288556, 6.737872062397385, -2.2217674863697363, -6.610348493218969, 2.782807998682069, 6.4348399142625, -3.333580454538404, -6.211876170721962, 3.8699778809340386, 5.9423430648768, -4.3879447262755, -5.627479639737401, 4.883507544998409, 5.268872809519615, -5.352805337613524, -4.868449358230261, 5.792119319106821, 4.42846534715928, -6.197901891508425, -3.9514929913793115, 6.566804600996418, 3.440405084320938, -6.895704866082216, -2.89835706796313, 7.181731271196583, 2.3287668640357175, -7.42228722931258, -1.7352925987290428, 7.61507282803431, 1.1218083696228494, -7.758104685788165, -0.49237821876096416, 7.849733658281115, -0.14877151011201464, -7.888660250154109, 0.7972812392598235, 7.873947602652454, -1.4486884471808472, -7.8050319450495556, 2.0984589687886497, 7.681730415376235, -2.7420190843467283, -7.504246174603971, 3.3747881688893187, 7.273170757665898, -3.992211668392129, -6.98948362445495, 4.58979416519146, 6.654548894049916, -5.16313229303921, -6.270109265767711, 5.707947261846867, 5.838277151065601, -6.220116753519672, -5.361523060661824, 6.69570595341031, 4.842661311399356, -7.130997486731045, -4.284833137137434, 7.522520035779674, 3.691487307250653, -7.867075422010167, -3.06635837492361, 8.161763946729348, 2.4134426952861876, -8.404007795520375, -1.7369723703662214, 8.5915723242455, 1.0413872937088526, -8.722585058636117, -0.33130548226698503, 8.79555225489689, -0.3885081034037336, -8.8093728853 ...

# %%
scatter(x2, y2, size=12, color="blue", fill_alpha=0.5,
        x_range=xr, y_range=yr, marker="square")
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#         <script type="text/javascript">
#             var all_models = [{"attributes": {"start": -20, "end": 20, "doc": null, "id": "176a249d-e451-4135-8ed1-b56b5310c086"}, "type": "Range1d", "id": "176a249d-e451-4135-8ed1-b56b5310c086"}, {"attributes": {"start": -20, "end": 20, "doc": null, "id": "d5cb44b4-d734-4312-a514-48a8a980ae82"}, "type": "Range1d", "id": "d5cb44b4-d734-4312-a514-48a8a980ae82"}, {"attributes": {"doc": null, "id": "e7e1cbf4-ba8d-4312-a117-d5a6725994a9"}, "type": "BasicTickFormatter", "id": "e7e1cbf4-ba8d-4312-a117-d5a6725994a9"}, {"attributes": {"doc": null, "id": "89a3a9ab-d2c8-4857-a655-37947f8bc0af"}, "type": "BasicTicker", "id": "89a3a9ab-d2c8-4857-a655-37947f8bc0af"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "doc": null, "bounds": "auto", "id": "b61f93e3-7eae-4e6e-90dc-07c7bd5c3886", "location": "min", "formatter": {"type": "BasicTickFormatter", "id": "e7e1cbf4-ba8d-4312-a117-d5a6725994a9"}, "ticker": {"type": "BasicTicker", "id": "89a3a9ab-d2c8-4857-a655-37947f8bc0af"}, "dimension": 0}, "type": "LinearAxis", "id": "b61f93e3-7eae-4e6e-90dc-07c7bd5c3886"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "doc": null, "axis": {"type": "LinearAxis", "id": "b61f93e3-7eae-4e6e-90dc-07c7bd5c3886"}, "id": "8e849b36-e7a9-4306-8c8e-2db1543ac359", "dimension": 0}, "type": "Grid", "id": "8e849b36-e7a9-4306-8c8e-2db1543ac359"}, {"attributes": {"doc": null, "id": "ef549f2e-d7d8-4728-91bb-710717d83495"}, "type": "BasicTickFormatter", "id": "ef549f2e-d7d8-4728-91bb-710717d83495"}, {"attributes": {"doc": null, "id": "afd6bb3e-05ca-4fc8-b74a-aec87dea6952"}, "type": "BasicTicker", "id": "afd6bb3e-05ca-4fc8-b74a-aec87dea6952"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "doc": null, "bounds": "auto", "id": "3dfc422f-6522-4f07-bdba-04735f68ffaf", "location": "min", "formatter": {"type": "BasicTickFormatter", "id": "ef549f2e-d7d8-4728-91bb-710717d83495"}, "ticker": {"type": "BasicTicker", "id": "afd6bb3e-05ca-4fc8-b74a-aec87dea6952"}, "dimension": 1}, "type": "LinearAxis", "id": "3dfc422f-6522-4f07-bdba-04735f68ffaf"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "doc": null, "axis": {"type": "LinearAxis", "id": "3dfc422f-6522-4f07-bdba-04735f68ffaf"}, "id": "20c241ef-ca6b-47b6-9eb6-99fb4f62e5b6", "dimension": 1}, "type": "Grid", "id": "20c241ef-ca6b-47b6-9eb6-99fb4f62e5b6"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "id": "f36a3e64-a27f-46ef-8ee3-7e9df0ad5982", "doc": null}, "type": "BoxZoomTool", "id": "f36a3e64-a27f-46ef-8ee3-7e9df0ad5982"}, {"attributes": {"doc": null, "tool": {"type": "BoxZoomTool", "id": "f36a3e64-a27f-46ef-8ee3-7e9df0ad5982"}, "id": "c0a5d464-d37f-42b9-97ca-715d7a806f06"}, "type": "BoxSelection", "id": "c0a5d464-d37f-42b9-97ca-715d7a806f06"}, {"attributes": {"column_names": ["x", "y"], "doc": null, "selected": [], "discrete_ranges": {}, "cont_ranges": {}, "data": {"y": [0.634236018676442, -0.07339007932661745, -1.0911744864689834, 0.206883634323373, 1.3897744763609043, -0.37794764711672, -1.611001026874622, 0.577333305825324, 1.7765992395462376, -0.7987068025104332, -1.8955626110323507, 1.0369353085735085, 1.972384975755608, -1.2874952628218377, -2.009638097421562, 1.5462161335248925, 2.0090145596627385, -1.8091576618082326, -1.9718209324049314, 2.072549776256705, 1.8992363470140068, -2.3327653151753656, -1.7924577387971148, 2.5863112487815965, 1.6527848377452106, -2.8298308543037294, -1.481670497238125, 3.060112542350688, 1.2807496701823042, -3.274102716219586, -1.0518544012990874, 3.4689209756071984, 0.7970191412532495, -3.6418765179162977, -0.5184790250638179, 3.7904849212566343, 0.21866281489361447, -3.9124847044693256, 0.09981834555383237, 4.005853200260817, -0.43418555154857513, -4.068821375508082, 0.7815095254599608, 4.099887304131736, -1.1387302949410312, -4.097828052324726, 1.5026787664880517, 4.061709779343205,  ...

# %%
scatter(x3, y3, size=12, fill_color="green", line_color="orange",
        x_range=xr, y_range=yr, marker="triangle")
# EXERCISE: Try panning and zooming one of the plots with another one visible!
# Set the plot_width and plot_height to smaller if necessary
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#         <script type="text/javascript">
#             var all_models = [{"attributes": {"start": -20, "end": 20, "doc": null, "id": "176a249d-e451-4135-8ed1-b56b5310c086"}, "type": "Range1d", "id": "176a249d-e451-4135-8ed1-b56b5310c086"}, {"attributes": {"start": -20, "end": 20, "doc": null, "id": "d5cb44b4-d734-4312-a514-48a8a980ae82"}, "type": "Range1d", "id": "d5cb44b4-d734-4312-a514-48a8a980ae82"}, {"attributes": {"doc": null, "id": "e7e1cbf4-ba8d-4312-a117-d5a6725994a9"}, "type": "BasicTickFormatter", "id": "e7e1cbf4-ba8d-4312-a117-d5a6725994a9"}, {"attributes": {"doc": null, "id": "89a3a9ab-d2c8-4857-a655-37947f8bc0af"}, "type": "BasicTicker", "id": "89a3a9ab-d2c8-4857-a655-37947f8bc0af"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "doc": null, "bounds": "auto", "id": "b61f93e3-7eae-4e6e-90dc-07c7bd5c3886", "location": "min", "formatter": {"type": "BasicTickFormatter", "id": "e7e1cbf4-ba8d-4312-a117-d5a6725994a9"}, "ticker": {"type": "BasicTicker", "id": "89a3a9ab-d2c8-4857-a655-37947f8bc0af"}, "dimension": 0}, "type": "LinearAxis", "id": "b61f93e3-7eae-4e6e-90dc-07c7bd5c3886"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "doc": null, "axis": {"type": "LinearAxis", "id": "b61f93e3-7eae-4e6e-90dc-07c7bd5c3886"}, "id": "8e849b36-e7a9-4306-8c8e-2db1543ac359", "dimension": 0}, "type": "Grid", "id": "8e849b36-e7a9-4306-8c8e-2db1543ac359"}, {"attributes": {"doc": null, "id": "ef549f2e-d7d8-4728-91bb-710717d83495"}, "type": "BasicTickFormatter", "id": "ef549f2e-d7d8-4728-91bb-710717d83495"}, {"attributes": {"doc": null, "id": "afd6bb3e-05ca-4fc8-b74a-aec87dea6952"}, "type": "BasicTicker", "id": "afd6bb3e-05ca-4fc8-b74a-aec87dea6952"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "doc": null, "bounds": "auto", "id": "3dfc422f-6522-4f07-bdba-04735f68ffaf", "location": "min", "formatter": {"type": "BasicTickFormatter", "id": "ef549f2e-d7d8-4728-91bb-710717d83495"}, "ticker": {"type": "BasicTicker", "id": "afd6bb3e-05ca-4fc8-b74a-aec87dea6952"}, "dimension": 1}, "type": "LinearAxis", "id": "3dfc422f-6522-4f07-bdba-04735f68ffaf"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "doc": null, "axis": {"type": "LinearAxis", "id": "3dfc422f-6522-4f07-bdba-04735f68ffaf"}, "id": "20c241ef-ca6b-47b6-9eb6-99fb4f62e5b6", "dimension": 1}, "type": "Grid", "id": "20c241ef-ca6b-47b6-9eb6-99fb4f62e5b6"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "id": "f36a3e64-a27f-46ef-8ee3-7e9df0ad5982", "doc": null}, "type": "BoxZoomTool", "id": "f36a3e64-a27f-46ef-8ee3-7e9df0ad5982"}, {"attributes": {"doc": null, "tool": {"type": "BoxZoomTool", "id": "f36a3e64-a27f-46ef-8ee3-7e9df0ad5982"}, "id": "c0a5d464-d37f-42b9-97ca-715d7a806f06"}, "type": "BoxSelection", "id": "c0a5d464-d37f-42b9-97ca-715d7a806f06"}, {"attributes": {"column_names": ["x", "y"], "doc": null, "selected": [], "discrete_ranges": {}, "cont_ranges": {}, "data": {"y": [0.634236018676442, -0.07339007932661745, -1.0911744864689834, 0.206883634323373, 1.3897744763609043, -0.37794764711672, -1.611001026874622, 0.577333305825324, 1.7765992395462376, -0.7987068025104332, -1.8955626110323507, 1.0369353085735085, 1.972384975755608, -1.2874952628218377, -2.009638097421562, 1.5462161335248925, 2.0090145596627385, -1.8091576618082326, -1.9718209324049314, 2.072549776256705, 1.8992363470140068, -2.3327653151753656, -1.7924577387971148, 2.5863112487815965, 1.6527848377452106, -2.8298308543037294, -1.481670497238125, 3.060112542350688, 1.2807496701823042, -3.274102716219586, -1.0518544012990874, 3.4689209756071984, 0.7970191412532495, -3.6418765179162977, -0.5184790250638179, 3.7904849212566343, 0.21866281489361447, -3.9124847044693256, 0.09981834555383237, 4.005853200260817, -0.43418555154857513, -4.068821375508082, 0.7815095254599608, 4.099887304131736, -1.1387302949410312, -4.097828052324726, 1.5026787664880517, 4.061709779343205,  ...

# %%
# %bokeh --show-off
# %bokeh --figure
# %bokeh --hold
# Out:
# Automatic show() is disabled.
# Automatic figure() is enabled.
# Automatic hold() is enabled.

# %%
# EXERCISE: Visualize all the sets of points on the same plot
scatter(x1, y1, size=12, color="red", alpha=0.5,
        x_range=xr, y_range=yr, tools=TOOLS)
scatter(x2, y2, size=12, color="blue", fill_alpha=0.5,
        x_range=xr, y_range=yr, marker="square")
scatter(x3, y3, size=12, fill_color="green", line_color="orange",
        x_range=xr, y_range=yr, marker="triangle")
# %bokeh --show
# Out:
# Automatic show() is enabled.
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#         <script type="text/javascript">
#             var all_models = [{"attributes": {"doc": null, "id": "563b3b2f-38ca-4d21-ba82-bde7a7ded9a5"}, "type": "BasicTickFormatter", "id": "563b3b2f-38ca-4d21-ba82-bde7a7ded9a5"}, {"attributes": {"start": -20, "end": 20, "doc": null, "id": "176a249d-e451-4135-8ed1-b56b5310c086"}, "type": "Range1d", "id": "176a249d-e451-4135-8ed1-b56b5310c086"}, {"attributes": {"start": -20, "end": 20, "doc": null, "id": "d5cb44b4-d734-4312-a514-48a8a980ae82"}, "type": "Range1d", "id": "d5cb44b4-d734-4312-a514-48a8a980ae82"}, {"attributes": {"doc": null, "id": "fe4dea7f-9194-4857-a4d3-5feede625c29"}, "type": "BasicTicker", "id": "fe4dea7f-9194-4857-a4d3-5feede625c29"}, {"attributes": {"plot": {"type": "Plot", "id": "2ee84e79-bc0a-4583-b2a7-a9c2ceb8e1bf"}, "doc": null, "bounds": "auto", "id": "c8005c5c-e512-4a87-b09e-d39efafd51f7", "location": "min", "formatter": {"type": "BasicTickFormatter", "id": "563b3b2f-38ca-4d21-ba82-bde7a7ded9a5"}, "ticker": {"type": "BasicTicker", "id": "fe4dea7f-9194-4857-a4d3-5feede625c29"}, "dimension": 0}, "type": "LinearAxis", "id": "c8005c5c-e512-4a87-b09e-d39efafd51f7"}, {"attributes": {"doc": null, "id": "9faabbd7-c3b6-4dce-b75c-609a4911f6e5"}, "type": "BasicTickFormatter", "id": "9faabbd7-c3b6-4dce-b75c-609a4911f6e5"}, {"attributes": {"doc": null, "id": "56605af9-15f8-4082-a4de-ed458eb1ddb2"}, "type": "BasicTicker", "id": "56605af9-15f8-4082-a4de-ed458eb1ddb2"}, {"attributes": {"plot": {"type": "Plot", "id": "2ee84e79-bc0a-4583-b2a7-a9c2ceb8e1bf"}, "doc": null, "bounds": "auto", "id": "d351a8ed-780e-4c29-8365-7ed1124240c9", "location": "min", "formatter": {"type": "BasicTickFormatter", "id": "9faabbd7-c3b6-4dce-b75c-609a4911f6e5"}, "ticker": {"type": "BasicTicker", "id": "56605af9-15f8-4082-a4de-ed458eb1ddb2"}, "dimension": 1}, "type": "LinearAxis", "id": "d351a8ed-780e-4c29-8365-7ed1124240c9"}, {"attributes": {"plot": {"type": "Plot", "id": "2ee84e79-bc0a-4583-b2a7-a9c2ceb8e1bf"}, "doc": null, "axis": {"type": "LinearAxis", "id": "d351a8ed-780e-4c29-8365-7ed1124240c9"}, "id": "13e7511d-7a6b-4fda-954e-d62fdf600353", "dimension": 1}, "type": "Grid", "id": "13e7511d-7a6b-4fda-954e-d62fdf600353"}, {"attributes": {"plot": {"type": "Plot", "id": "2ee84e79-bc0a-4583-b2a7-a9c2ceb8e1bf"}, "id": "06df78e5-12f4-4135-9187-1a41f847d002", "doc": null}, "type": "BoxZoomTool", "id": "06df78e5-12f4-4135-9187-1a41f847d002"}, {"attributes": {"doc": null, "tool": {"type": "BoxZoomTool", "id": "06df78e5-12f4-4135-9187-1a41f847d002"}, "id": "f5fb3be7-b3ca-4aa6-a90e-2b9911571db2"}, "type": "BoxSelection", "id": "f5fb3be7-b3ca-4aa6-a90e-2b9911571db2"}, {"attributes": {"column_names": ["x", "y"], "doc": null, "selected": [], "discrete_ranges": {}, "cont_ranges": {}, "data": {"y": [0.634236018676442, -0.07339007932661745, -1.0911744864689834, 0.206883634323373, 1.3897744763609043, -0.37794764711672, -1.611001026874622, 0.577333305825324, 1.7765992395462376, -0.7987068025104332, -1.8955626110323507, 1.0369353085735085, 1.972384975755608, -1.2874952628218377, -2.009638097421562, 1.5462161335248925, 2.0090145596627385, -1.8091576618082326, -1.9718209324049314, 2.072549776256705, 1.8992363470140068, -2.3327653151753656, -1.7924577387971148, 2.5863112487815965, 1.6527848377452106, -2.8298308543037294, -1.481670497238125, 3.060112542350688, 1.2807496701823042, -3.274102716219586, -1.0518544012990874, 3.4689209756071984, 0.7970191412532495, -3.6418765179162977, -0.5184790250638179, 3.7904849212566343, 0.21866281489361447, -3.9124847044693256, 0.09981834555383237, 4.005853200260817, -0.43418555154857513, -4.068821375508082, 0.7815095254599608, 4.099887304131736, -1.1387302949410312, -4.097828052324726, 1.5026787664880517, 4.061709779343205, -1.8700998532866944, -3.990895893269013, 2.237676851354443, 3.8850531325372057, -2.6020567813451025, -3.744155472136654, 2.959876429335713, 3.5684857792363625, -3.3077888312937698, -3.3586351672112165, 3.6424899546137297, 3.115500020047846, -3.9607453373796577, -2.8402766811475177, 4.259416452727287, 2.5 ...

# %%
# %bokeh --hold-off
# %bokeh --show-off
# Out:
# Automatic hold() is disabled.
# Automatic show() is disabled.

# %%
# Lets plot 4000 circles, you can play around with this if you like
N = 4000

# %%
# Create a bunch of random points, radii and colors for plotting
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (r, g, 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))
]

# %%
# EXERCISE: use the `circle` renderer to scatter all the circles. Set the
# 'fill_color' to the colors above, the 'line_color' to None, and the 'radius'
# to the radii. Also try setting the fill_alpha to something less than one.
# Use TOOLS from above to set a tools parameter.
circle(x, y, radius=radii,
       fill_color=colors, fill_alpha=0.6,
       line_color=None, Title="Colorful Scatter")
# %bokeh --show
# Out:
# Automatic show() is enabled.
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#         <script type="text/javascript">
#             var all_models = [{"attributes": {"doc": null, "id": "afd6bb3e-05ca-4fc8-b74a-aec87dea6952"}, "type": "BasicTicker", "id": "afd6bb3e-05ca-4fc8-b74a-aec87dea6952"}, {"attributes": {"start": -20, "end": 20, "doc": null, "id": "176a249d-e451-4135-8ed1-b56b5310c086"}, "type": "Range1d", "id": "176a249d-e451-4135-8ed1-b56b5310c086"}, {"attributes": {"start": -20, "end": 20, "doc": null, "id": "d5cb44b4-d734-4312-a514-48a8a980ae82"}, "type": "Range1d", "id": "d5cb44b4-d734-4312-a514-48a8a980ae82"}, {"attributes": {"doc": null, "id": "e7e1cbf4-ba8d-4312-a117-d5a6725994a9"}, "type": "BasicTickFormatter", "id": "e7e1cbf4-ba8d-4312-a117-d5a6725994a9"}, {"attributes": {"doc": null, "id": "89a3a9ab-d2c8-4857-a655-37947f8bc0af"}, "type": "BasicTicker", "id": "89a3a9ab-d2c8-4857-a655-37947f8bc0af"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "doc": null, "bounds": "auto", "id": "b61f93e3-7eae-4e6e-90dc-07c7bd5c3886", "location": "min", "formatter": {"type": "BasicTickFormatter", "id": "e7e1cbf4-ba8d-4312-a117-d5a6725994a9"}, "ticker": {"type": "BasicTicker", "id": "89a3a9ab-d2c8-4857-a655-37947f8bc0af"}, "dimension": 0}, "type": "LinearAxis", "id": "b61f93e3-7eae-4e6e-90dc-07c7bd5c3886"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "doc": null, "axis": {"type": "LinearAxis", "id": "b61f93e3-7eae-4e6e-90dc-07c7bd5c3886"}, "id": "8e849b36-e7a9-4306-8c8e-2db1543ac359", "dimension": 0}, "type": "Grid", "id": "8e849b36-e7a9-4306-8c8e-2db1543ac359"}, {"attributes": {"doc": null, "id": "ef549f2e-d7d8-4728-91bb-710717d83495"}, "type": "BasicTickFormatter", "id": "ef549f2e-d7d8-4728-91bb-710717d83495"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "doc": null, "bounds": "auto", "id": "3dfc422f-6522-4f07-bdba-04735f68ffaf", "location": "min", "formatter": {"type": "BasicTickFormatter", "id": "ef549f2e-d7d8-4728-91bb-710717d83495"}, "ticker": {"type": "BasicTicker", "id": "afd6bb3e-05ca-4fc8-b74a-aec87dea6952"}, "dimension": 1}, "type": "LinearAxis", "id": "3dfc422f-6522-4f07-bdba-04735f68ffaf"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "doc": null, "axis": {"type": "LinearAxis", "id": "3dfc422f-6522-4f07-bdba-04735f68ffaf"}, "id": "20c241ef-ca6b-47b6-9eb6-99fb4f62e5b6", "dimension": 1}, "type": "Grid", "id": "20c241ef-ca6b-47b6-9eb6-99fb4f62e5b6"}, {"attributes": {"plot": {"type": "Plot", "id": "2bf7c2a0-2a3e-420c-be44-8b4f2daf0568"}, "id": "f36a3e64-a27f-46ef-8ee3-7e9df0ad5982", "doc": null}, "type": "BoxZoomTool", "id": "f36a3e64-a27f-46ef-8ee3-7e9df0ad5982"}, {"attributes": {"doc": null, "tool": {"type": "BoxZoomTool", "id": "f36a3e64-a27f-46ef-8ee3-7e9df0ad5982"}, "id": "c0a5d464-d37f-42b9-97ca-715d7a806f06"}, "type": "BoxSelection", "id": "c0a5d464-d37f-42b9-97ca-715d7a806f06"}, {"attributes": {"column_names": ["x", "y"], "doc": null, "selected": [], "discrete_ranges": {}, "cont_ranges": {}, "data": {"y": [0.634236018676442, -0.07339007932661745, -1.0911744864689834, 0.206883634323373, 1.3897744763609043, -0.37794764711672, -1.611001026874622, 0.577333305825324, 1.7765992395462376, -0.7987068025104332, -1.8955626110323507, 1.0369353085735085, 1.972384975755608, -1.2874952628218377, -2.009638097421562, 1.5462161335248925, 2.0090145596627385, -1.8091576618082326, -1.9718209324049314, 2.072549776256705, 1.8992363470140068, -2.3327653151753656, -1.7924577387971148, 2.5863112487815965, 1.6527848377452106, -2.8298308543037294, -1.481670497238125, 3.060112542350688, 1.2807496701823042, -3.274102716219586, -1.0518544012990874, 3.4689209756071984, 0.7970191412532495, -3.6418765179162977, -0.5184790250638179, 3.7904849212566343, 0.21866281489361447, -3.9124847044693256, 0.09981834555383237, 4.005853200260817, -0.43418555154857513, -4.068821375508082, 0.7815095254599608, 4.099887304131736, -1.1387302949410312, -4.097828052324726, 1.5026787664880517, 4.061709779343205,  ...
